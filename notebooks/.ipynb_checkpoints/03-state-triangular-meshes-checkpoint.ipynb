# %% [markdown]
# # State Polygons
#
# ## Triangular Meshes
#
# This notebook considers states as polygons for the purposes of generating triangular meshes. The mesh generator will use the Delaunay triangulation and some Julia code to generate the triangular mesh of the state. In order to use the Julia code, we use the IPython magic from the `julia` library.

# %%
# %load_ext julia.magic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact
import ipywidgets as widgets
import pickle
from utils import *
# Out:
# Initializing Julia runtime. This may take some time...
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/julia/magic.py:152: UserWarning: Incompatible upstream libraries. Got ImportError: No module named 'prompt_toolkit.lexers'
#   warnings.warn(template.format(err))

# %% [markdown]
# We begin by unpickling the dictionary that was created in the last notebook.

# %%
with open("../data/polygons-pickle.txt", "r+b") as f:
    polygons = pickle.load(f)

# %% [markdown]
# ### Plotting Polygons
#
# Before creating the mesh generator, we first need to plot polygons. To that end, we define a function `plot_polygon` below which plots a _closed_ polygon from a list of points.

# %%
def plot_polygon(pv):
    """
    Plots a closed polygon from a list of points (list of lists)
    
    Arguments:
        pv - list of points (list of lists)
    """
    assert pv[0] == pv[-1], "Polygon must be closed"
    x, y = [vertex[0] for vertex in pv], [vertex[1] for vertex in pv]
    plt.plot(x, y, color = "black")
    plt.fill(x, y, color = "#8bd0d3")
    plt.axis(option = "equal");
    
# sample polygon
poly = [[0,0], [1,2], [2,4], [3,4.5], [4,3], [3,2.5], [1,0], [0,0]]
plot_polygon(poly)

# %% [markdown]
# ### Mesh Generator
#
# The code that runs the algorithm to generate the triangular mesh is written in Julia. In order to use it, we make use of some IPython magic that will allow us to run Julia code in this Python notebook. We start by importing the file that contains the code we need for the mesh generator, [`mesh-generator.jl`](mesh-generator.jl).

# %%
# %julia include("mesh-generator.jl")
# Out:
# <PyCall.jlwrap pmesh>

# %% [markdown]
# The function `pmesh` defined in that file generates a triangular mesh of a polygon by returning an array of nodes `p` and an array of triangles `t`. `p` contains coordinates that describe points in the plane. `t` contains arrays of indices which map to elements in `p` and define triangles.
#
# For example, if we had `p` and `t` defined as follows:
#
# ```python
# p = [[0,0], [1,1], [1,2], [3,2], [3,1], [2,0], [0,0]]
# t = [[2, 1, 4], ...]
# ```
#
# then one of the triangles in the mesh would have vertices $(1,2)$, $(1,1)$, and $(3,1)$.

# %%
# %%julia
# poly = [[$poly[p,1], $poly[p,2]] for p in 1:size($poly, 1)]
# p,t = pmesh(poly, 0.2);
# Out:
# ([array([0, 0], dtype=int64),
#   array([0.08333333, 0.16666667]),
#   array([0.16666667, 0.33333333]),
#   array([0.25, 0.5 ]),
#   array([0.33333333, 0.66666667]),
#   array([0.41666667, 0.83333333]),
#   array([0.5, 1. ]),
#   array([0.58333333, 1.16666667]),
#   array([0.66666667, 1.33333333]),
#   array([0.75, 1.5 ]),
#   array([0.83333333, 1.66666667]),
#   array([0.91666667, 1.83333333]),
#   array([1, 2], dtype=int64),
#   array([1.08333333, 2.16666667]),
#   array([1.16666667, 2.33333333]),
#   array([1.25, 2.5 ]),
#   array([1.33333333, 2.66666667]),
#   array([1.41666667, 2.83333333]),
#   array([1.5, 3. ]),
#   array([1.58333333, 3.16666667]),
#   array([1.66666667, 3.33333333]),
#   array([1.75, 3.5 ]),
#   array([1.83333333, 3.66666667]),
#   array([1.91666667, 3.83333333]),
#   array([2, 4], dtype=int64),
#   array([2.16666667, 4.08333333]),
#   array([2.33333333, 4.16666667]),
#   array([2.5 , 4.25]),
#   array([2.66666667, 4.33333333]),
#   array([2.83333333, 4.41666667]),
#   array([3. , 4.5]),
#   array([3.1 , 4.35]),
#   array([3.2, 4.2]),
#   array([3.3 , 4.05]),
#   array([3.4, 3.9]),
#   array([3.5 , 3.75]),
#   array([3.6, 3.6]),
#   array([3.7 , 3.45]),
#   array([3.8, 3.3]),
#   array([3.9 , 3.15]),
#   array([4, 3], dtype=int64),
#   array([3.83333333, 2.91666667]),
#   array([3.66666667, 2.83333333]),
#   array([3.5 , 2.75]),
#   array([3.33333333, 2.66666667]),
#   array([3.16666667, 2.58333333]),
#   array([3. , 2.5]),
#   array([2.88235294, 2.35294118]),
#   array([2.76470588, 2.20588235]),
#   array([2.64705882, 2.05882353]),
#   array([2.52941176, 1.91176471]),
#   array([2.41176471, 1.76470588]),
#   array([2.29411765, 1.61764706]),
#   array([2.17647059, 1.47058824]),
#   array([2.05882353, 1.32352941]),
#   array([1.94117647, 1.17647059]),
#   array([1.82352941, 1.02941176]),
#   array([1.70588235, 0.88235294]),
#   array([1.58823529, 0.73529412]),
#   array([1.47058824, 0.58823529]),
#   array([1.35294118, 0.44117647]),
#   array([1.23529412, 0.29411765]),
#   array([1.11764706, 0.14705882]),
#   array([1, 0], dtype=int64),
#   array([0.8, 0. ]),
#   array([0.6, 0. ]),
#   array([0.4, 0. ]),
#   array([0.2, 0. ]),
#   array([0, 0], dtype=int64),
#   array([2.69482323, 3.3459596 ]),
#   array([2.2215943 , 2.74477196]),
#   array([1.85117346, 2.16441289]),
#   array([1.51265594, 1.63550259]),
#   array([1.20677078, 1.15654424]),
#   array([3.21692532, 3.20944991]),
#   array([2.19466833, 3.25281342]),
#   array([2.68713877, 2.86516197]),
#   array([0.93105855, 0.72759092]),
#   array([2.82762542, 3.843835  ]),
#   array([2.27445862, 2.30263849]),
#   array([1.79900177, 2.60610428]),
#   array([2.37486414, 3.67462088]),
#   array([0.66133951, 0.41120247]),
#   array([1.8966105 , 1.76254637]),
#   array([1.46687783, 2.03758741]),
#   array([3.13581772, 3.59631941]),
#   array([1.16694149, 1.51913653]),
#   array([1.55226813, 1.27304895]),
#   array([2.56215154, 2.52421791]),
#   array([3.03545117, 2.90894149]),
#   array([1.92087203, 2.98356808]),
#   array([2.15325872, 1.98521265]),
#   array([1.56107121, 2.36383102]),
#   array([0.89332006, 1.05493203]),
#   array([1.24498678, 0.82889621]),
#   array([3.52858273, 3.12516684]),
#   array([2.4015916 , 3.00904599]),
#   array([1.24966355, 1.81726546]),
#   array([1.78813619, 1.47298939]),
#   array([2.53520453, 3.93592989]),
#   array([2.10601652, 3.54007888]),
#   array([0.96344527, 0.42682039]),
#   array([2.65174766, 3.62409886]),
#   array([2.42532443, 3.4036708 ]),
#   array([2.00627814, 2.40666045]),
#   array([0.65518617, 0.68960921]),
#   array([2.9777145, 3.361236 ]),
#   array([0.96697589, 1.32426039]),
#   array([1.45750141, 1.01024139]),
#   array([0.43018607, 0.26946359]),
#   array([3.09905349, 3.86617223]),
#   array([3.36913678, 3.44329811]),
#   array([3.30862889, 2.94902154]),
#   array([2.83411803, 3.10327306]),
#   array([1.92464298, 3.25356816]),
#   array([1.70470347, 2.8449558 ]),
#   array([1.71050677, 1.94500649]),
#   array([2.90321485, 4.12952607]),
#   array([2.52358246, 2.27673881]),
#   array([1.15228861, 0.59419691]),
#   array([2.78786499, 2.63485492]),
#   array([2.46803772, 2.75210091]),
#   array([1.98429416, 2.75468544]),
#   array([2.32617381, 2.53304902]),
#   array([0.71273444, 0.91237127]),
#   array([1.38658115, 1.4383326 ]),
#   array([2.36800414, 2.08506957]),
#   array([1.56160184, 2.60127938]),
#   array([0.82183577, 0.23634308]),
#   array([1.37213673, 2.24166076]),
#   array([2.12170037, 1.76234596]),
#   array([2.1602978 , 3.01393014]),
#   array([2.67922647, 4.10873278]),
#   array([2.3058201 , 3.89683391]),
#   array([2.12805354, 3.7620652 ]),
#   array([2.89257712, 3.58920152]),
#   array([2.60153026, 3.13109344]),
#   array([1.63793062, 2.16492049]),
#   array([1.94064959, 1.97102758]),
#   array([1.98288054, 1.56513085]),
#   array([1.25167826, 2.03251537]),
#   array([1.04655274, 0.90675196]),
#   array([3.53696383, 3.32838983]),
#   array([1.78437554, 2.37796031]),
#   array([2.07258109, 2.19342995]),
#   array([1.07733818, 1.70453977]),
#   array([1.75786002, 1.26960992]),
#   array([0.62169893, 0.20191402]),
#   array([1.45452242, 1.83253235]),
#   array([1.71583437, 1.66517212]),
#   array([3.03764042, 3.11266888]),
#   array([1.93624328, 3.44688864]),
#   array([0.96891621, 1.52230146]),
#   array([1.63662326, 1.09414112]),
#   array([1.3196034 , 1.63731826]),
#   array([1.59548414, 1.46116339]),
#   array([3.07771897, 4.05480014]),
#   array([1.77677859, 3.12060693]),
#   array([3.33166785, 3.64055454]),
#   array([2.98296689, 2.70748398]),
#   array([0.5036085 , 0.54698768]),
#   array([2.38874048, 3.20784492]),
#   array([3.71842981, 3.07568672]),
#   array([0.80543156, 0.55365856]),
#   array([2.0961479 , 2.58704416]),
#   array([1.42919043, 0.82822511]),
#   array([0.81357889, 1.22147549]),
#   array([2.65392875, 3.80260783]),
#   array([1.15237378, 1.33405264]),
#   array([3.17121789, 3.4018042 ]),
#   array([1.39024738, 1.18298267]),
#   array([2.24606742, 3.42598745]),
#   array([3.19147552, 2.7965131 ]),
#   array([3.4972576 , 2.93888117]),
#   array([1.03187992, 1.16177459]),
#   array([1.28312413, 0.99939717]),
#   array([2.85652209, 2.92502504]),
#   array([3.25904552, 3.79840295]),
#   array([1.31284729, 0.66643769]),
#   array([2.73365314, 2.45989348]),
#   array([1.42783333, 2.48285354]),
#   array([3.35800432, 3.11276769]),
#   array([2.31655699, 1.91487145]),
#   array([2.49647053, 3.55709444]),
#   array([1.62006075, 1.80331664]),
#   array([2.94369631, 4.2914519 ]),
#   array([2.84086612, 3.26846505]),
#   array([2.97237922, 3.74515803]),
#   array([1.13185951, 0.42702619]),
#   array([0.27005489, 0.17320509]),
#   array([0.99009362, 0.25913066]),
#   array([1.56372156, 2.76389175]),
#   array([1.66335228, 3.00301637]),
#   array([0.3946178 , 0.42734806]),
#   array([2.83178573, 3.43661728]),
#   array([0.72582365, 1.07910318]),
#   array([2.27867445, 2.8993298 ]),
#   array([2.05936826, 3.15036614]),
#   array([0.87898534, 0.88743345]),
#   array([2.52802608, 2.90467797]),
#   array([1.99733476, 3.66295492]),
#   array([2.54086622, 3.2851198 ]),
#   array([2.10756608, 2.86036259]),
#   array([2.80195739, 4.00347179]),
#   array([0.99426488, 0.58226797]),
#   array([2.63171386, 2.70374139]),
#   array([0.5764717 , 0.82875881]),
#   array([3.65878631, 3.22436362]),
#   array([2.40228646, 4.02331687]),
#   array([1.30365101, 1.30944063]),
#   array([1.09422148, 1.866811  ]),
#   array([1.89829512, 1.35264727]),
#   array([2.70595641, 3.01796499]),
#   array([2.78531867, 3.69744278]),
#   array([2.66814392, 2.32298135]),
#   array([2.43996682, 2.41651513]),
#   array([1.85845423, 2.84304416]),
#   array([2.17215444, 2.43659755]),
#   array([2.51267346, 2.12661742]),
#   array([2.08539646, 3.37640344]),
#   array([3.37888086, 3.27751724]),
#   array([2.22386742, 3.64046658]),
#   array([3.01674524, 3.50569338]),
#   array([3.18603927, 3.05221435]),
#   array([0.81388537, 0.3901319 ]),
#   array([1.94458581, 2.54997551]),
#   array([1.09473088, 0.7488879 ]),
#   array([2.52937158, 4.10293749]),
#   array([2.22517203, 2.15255254]),
#   array([1.6824288 , 2.49903691]),
#   array([2.43762887, 3.81595546]),
#   array([0.48747348, 0.12662353]),
#   array([2.44721236, 2.61012459]),
#   array([3.51516766, 3.47656826]),
#   array([2.1461301, 3.9228471]),
#   array([2.39223095, 2.22438086]),
#   array([2.95589199, 3.94550059]),
#   array([2.84712036, 2.77404205]),
#   array([1.23341311, 2.18229735]),
#   array([2.12568691, 1.6120746 ]),
#   array([1.81534569, 3.35713488]),
#   array([2.78119878, 4.22708659]),
#   array([3.07725904, 3.25372755]),
#   array([1.90736793, 2.29921155]),
#   array([0.8248181 , 1.37055991]),
#   array([3.36498618, 2.8116943 ]),
#   array([1.55853216, 0.90131707]),
#   array([3.05486712, 4.1981348 ]),
#   array([2.28276018, 3.10117911]),
#   array([2.35001158, 3.5298187 ]),
#   array([0.9       , 0.10994123]),
#   array([1.49704485, 2.17562092]),
#   array([2.05311867, 1.88572497]),
#   array([1.60409139, 2.03182003]),
#   array([1.744346  , 2.07810694]),
#   array([1.8338687 , 1.88469177]),
#   array([0.73797542, 0.12491071]),
#   array([3.63256193, 2.96732223]),
#   array([2.62302208, 3.47724492]),
#   array([0.78489242, 0.7683766 ]),
#   array([1.67755493, 2.29453598]),
#   array([1.97184645, 2.10285405]),
#   array([0.4928203 , 0.70008381]),
#   array([1.1157218 , 1.03866504]),
#   array([2.86136745, 2.51620066]),
#   array([2.00909462, 1.69414398]),
#   array([1.35749194, 2.11083345]),
#   array([2.52684901, 3.70011792]),
#   array([1.85347318, 1.62613783]),
#   array([1.36149386, 1.94103746]),
#   array([1.32806364, 2.37886535]),
#   array([2.26661524, 1.77794297]),
#   array([2.67571362, 3.94153081]),
#   array([0.6435837, 0.5500814]),
#   array([2.22387456, 2.61420855]),
#   array([3.22195178, 3.93357277]),
#   array([0.55661164, 0.32264029]),
#   array([3.11030939, 2.69792538]),
#   array([1.69294793, 2.70227454]),
#   array([2.47498574, 3.11360531]),
#   array([3.13740257, 3.73396608]),
#   array([1.75729847, 1.14038042]),
#   array([0.70892326, 0.29379149]),
#   array([0.96078236, 1.65051243]),
#   array([3.25511185, 3.52382586])],
#  [array([ 2, 69, 68], dtype=int64),
#   array([ 68,  67, 190], dtype=int64),
#   array([232,  67,  66], dtype=int64),
#   array([232, 190,  67], dtype=int64),
#   array([  3,   2, 190], dtype=int64),
#   array([190, 110,   3], dtype=int64),
#   array([110, 190, 232], dtype=int64),
#   array([  2,  68, 190], dtype=int64),
#   array([194,   3, 110], dtype=int64),
#   array([232, 148, 110], dtype=int64),
#   array([148, 277, 110], dtype=int64),
#   array([148,  66, 257], dtype=int64),
#   array([129, 257, 251], dtype=int64),
#   array([ 65, 257,  66], dtype=int64),
#   array([148, 257, 283], dtype=int64),
#   array([194, 110, 277], dtype=int64),
#   array([ 83, 277, 283], dtype=int64),
#   array([283, 129, 225], dtype=int64),
#   array([283, 277, 148], dtype=int64),
#   array([102, 164, 225], dtype=int64),
#   array([283, 225,  83], dtype=int64),
#   array([257, 129, 283], dtype=int64),
#   array([ 83, 225, 164], dtype=int64),
#   array([257,  65, 251], dtype=int64),
#   array([148, 232,  66], dtype=int64),
#   array([161, 277,  83], dtype=int64),
#   array([  5,   4, 194], dtype=int64),
#   array([194, 161,   5], dtype=int64),
#   array([194, 277, 161], dtype=int64),
#   array([  4,   3, 194], dtype=int64),
#   array([  5, 161, 263], dtype=int64),
#   array([  6, 263, 207], dtype=int64),
#   array([263,   6,   5], dtype=int64),
#   array([  8,   7, 196], dtype=int64),
#   array([207,   7,   6], dtype=int64),
#   array([125,   7, 207], dtype=int64),
#   array([207, 263, 106], dtype=int64),
#   array([263, 161, 106], dtype=int64),
#   array([207, 106, 260], dtype=int64),
#   array([106, 274, 164], dtype=int64),
#   array([199, 260,  78], dtype=int64),
#   array([164, 260, 106], dtype=int64),
#   array([ 83, 274, 161], dtype=int64),
#   array([260, 125, 207], dtype=int64),
#   array([196, 167,   8], dtype=int64),
#   array([  7, 125, 196], dtype=int64),
#   array([167, 196,  94], dtype=int64),
#   array([125,  94, 196], dtype=int64),
#   array([199,  94, 125], dtype=int64),
#   array([167,   9,   8], dtype=int64),
#   array([125, 260, 199], dtype=int64),
#   array([245,   9, 167], dtype=int64),
#   array([ 78, 260, 164], dtype=int64),
#   array([106, 161, 274], dtype=int64),
#   array([ 83, 164, 274], dtype=int64),
#   array([225, 129, 191], dtype=int64),
#   array([191, 102, 225], dtype=int64),
#   array([191, 251,  63], dtype=int64),
#   array([ 64,  63, 251], dtype=int64),
#   array([251,  65,  64], dtype=int64),
#   array([189, 191,  62], dtype=int64),
#   array([164, 205,  78], dtype=int64),
#   array([164, 102, 205], dtype=int64),
#   array([227, 205, 120], dtype=int64),
#   array([189, 205, 102], dtype=int64),
#   array([120, 205, 189], dtype=int64),
#   array([205, 227,  78], dtype=int64),
#   array([102, 191, 189], dtype=int64),
#   array([142,  78, 227], dtype=int64),
#   array([191,  63,  62], dtype=int64),
#   array([142, 199,  78], dtype=int64),
#   array([189,  61, 120], dtype=int64),
#   array([ 61, 189,  62], dtype=int64),
#   array([120,  61, 179], dtype=int64),
#   array([179,  61,  60], dtype=int64),
#   array([ 95, 179, 166], dtype=int64),
#   array([ 95, 227, 179], dtype=int64),
#   array([247, 166,  59], dtype=int64),
#   array([166, 179,  60], dtype=int64),
#   array([ 95, 166, 176], dtype=int64),
#   array([ 60,  59, 166], dtype=int64),
#   array([ 58, 247,  59], dtype=int64),
#   array([179, 227, 120], dtype=int64),
#   array([142, 227,  95], dtype=int64),
#   array([ 94, 142, 264], dtype=int64),
#   array([ 94, 199, 142], dtype=int64),
#   array([264, 176,  74], dtype=int64),
#   array([264, 142,  95], dtype=int64),
#   array([176, 264,  95], dtype=int64),
#   array([ 94, 264, 175], dtype=int64),
#   array([108, 175, 169], dtype=int64),
#   array([108, 167, 175], dtype=int64),
#   array([169,  74, 210], dtype=int64),
#   array([ 74, 169, 175], dtype=int64),
#   array([171, 210,  74], dtype=int64),
#   array([ 87, 169, 210], dtype=int64),
#   array([175, 264,  74], dtype=int64),
#   array([245, 167, 108], dtype=int64),
#   array([ 74, 176, 171], dtype=int64),
#   array([175, 167,  94], dtype=int64),
#   array([109, 247, 154], dtype=int64),
#   array([109, 176, 166], dtype=int64),
#   array([154,  57, 282], dtype=int64),
#   array([154, 247,  58], dtype=int64),
#   array([ 58,  57, 154], dtype=int64),
#   array([109, 154, 171], dtype=int64),
#   array([171,  88, 210], dtype=int64),
#   array([171, 154,  88], dtype=int64),
#   array([282,  56, 147], dtype=int64),
#   array([ 56, 282,  57], dtype=int64),
#   array([147,  56, 212], dtype=int64),
#   array([147,  88, 154], dtype=int64),
#   array([282, 147, 154], dtype=int64),
#   array([210,  88, 126], dtype=int64),
#   array([109, 171, 176], dtype=int64),
#   array([247, 109, 166], dtype=int64),
#   array([147, 156,  88], dtype=int64),
#   array([251, 191, 129], dtype=int64),
#   array([153, 108, 169], dtype=int64),
#   array([ 10, 245, 153], dtype=int64),
#   array([245,  10,   9], dtype=int64),
#   array([284, 153, 146], dtype=int64),
#   array([ 10, 153,  11], dtype=int64),
#   array([108, 153, 245], dtype=int64),
#   array([ 11, 153, 284], dtype=int64),
#   array([ 11, 284,  12], dtype=int64),
#   array([211,  12, 146], dtype=int64),
#   array([ 12, 211,  13], dtype=int64),
#   array([284, 146,  12], dtype=int64),
#   array([153,  87, 146], dtype=int64),
#   array([155,  87, 126], dtype=int64),
#   array([153, 169,  87], dtype=int64),
#   array([ 85, 149, 254], dtype=int64),
#   array([156,  73, 126], dtype=int64),
#   array([126,  88, 156], dtype=int64),
#   array([155, 126,  73], dtype=int64),
#   array([141, 211,  98], dtype=int64),
#   array([146,  98, 211], dtype=int64),
#   array([149, 270,  98], dtype=int64),
#   array([149, 155,  73], dtype=int64),
#   array([270, 149,  85], dtype=int64),
#   array([149,  98, 155], dtype=int64),
#   array([155,  98, 146], dtype=int64),
#   array([ 13, 211, 141], dtype=int64),
#   array([ 73, 185, 149], dtype=int64),
#   array([146,  87, 155], dtype=int64),
#   array([210, 126,  87], dtype=int64),
#   array([270, 141,  98], dtype=int64),
#   array([ 14, 239,  15], dtype=int64),
#   array([239,  14, 141], dtype=int64),
#   array([141, 267, 239], dtype=int64),
#   array([141, 270, 267], dtype=int64),
#   array([ 14,  13, 141], dtype=int64),
#   array([239, 267, 130], dtype=int64),
#   array([ 16,  15, 271], dtype=int64),
#   array([181,  16, 271], dtype=int64),
#   array([271,  15, 239], dtype=int64),
#   array([ 93, 271, 130], dtype=int64),
#   array([ 16, 181,  17], dtype=int64),
#   array([239, 130, 271], dtype=int64),
#   array([267, 252, 130], dtype=int64),
#   array([252,  93, 130], dtype=int64),
#   array([252, 267,  85], dtype=int64),
#   array([ 93, 181, 271], dtype=int64),
#   array([254, 252,  85], dtype=int64),
#   array([252, 138,  93], dtype=int64),
#   array([181,  93, 128], dtype=int64),
#   array([ 19,  18, 192], dtype=int64),
#   array([ 19, 192, 116], dtype=int64),
#   array([128, 279, 192], dtype=int64),
#   array([ 19, 193,  20], dtype=int64),
#   array([192,  18,  17], dtype=int64),
#   array([128, 192,  17], dtype=int64),
#   array([230, 128,  93], dtype=int64),
#   array([128,  17, 181], dtype=int64),
#   array([270,  85, 267], dtype=int64),
#   array([156, 150,  73], dtype=int64),
#   array([185, 117, 254], dtype=int64),
#   array([256, 117, 185], dtype=int64),
#   array([256, 185, 150], dtype=int64),
#   array([150, 185,  73], dtype=int64),
#   array([156,  99, 150], dtype=int64),
#   array([255, 117, 256], dtype=int64),
#   array([261,  93, 138], dtype=int64),
#   array([138, 254, 255], dtype=int64),
#   array([144, 261,  72], dtype=int64),
#   array([138,  72, 261], dtype=int64),
#   array([138, 255,  72], dtype=int64),
#   array([261, 144, 230], dtype=int64),
#   array([254, 117, 255], dtype=int64),
#   array([261, 230,  93], dtype=int64),
#   array([ 99, 269, 150], dtype=int64),
#   array([185, 254, 149], dtype=int64),
#   array([ 84, 256, 150], dtype=int64),
#   array([266,  84, 269], dtype=int64),
#   array([140, 269,  99], dtype=int64),
#   array([ 55, 140, 212], dtype=int64),
#   array([ 99, 212, 140], dtype=int64),
#   array([139,  84, 253], dtype=int64),
#   array([139, 255, 256], dtype=int64),
#   array([255, 139,  72], dtype=int64),
#   array([ 72, 262, 244], dtype=int64),
#   array([262,  72, 139], dtype=int64),
#   array([ 92, 262, 139], dtype=int64),
#   array([105, 144, 244], dtype=int64),
#   array([256,  84, 139], dtype=int64),
#   array([ 72, 244, 144], dtype=int64),
#   array([145, 244, 262], dtype=int64),
#   array([ 84, 150, 269], dtype=int64),
#   array([156, 147,  99], dtype=int64),
#   array([226, 144, 105], dtype=int64),
#   array([116, 192, 279], dtype=int64),
#   array([279, 230,  81], dtype=int64),
#   array([217, 193, 116], dtype=int64),
#   array([279, 217, 116], dtype=int64),
#   array([144,  81, 230], dtype=int64),
#   array([116, 193,  19], dtype=int64),
#   array([ 20, 193, 158], dtype=int64),
#   array([ 20, 158,  21], dtype=int64),
#   array([ 21, 241,  22], dtype=int64),
#   array([241,  21, 158], dtype=int64),
#   array([115, 241, 158], dtype=int64),
#   array([ 22, 241, 152], dtype=int64),
#   array([158, 193,  91], dtype=int64),
#   array([ 81, 217, 279], dtype=int64),
#   array([128, 230, 279], dtype=int64),
#   array([ 91, 115, 158], dtype=int64),
#   array([ 91, 217, 123], dtype=int64),
#   array([123, 217,  81], dtype=int64),
#   array([165, 123, 226], dtype=int64),
#   array([ 81, 226, 123], dtype=int64),
#   array([115,  91, 198], dtype=int64),
#   array([ 24,  23, 201], dtype=int64),
#   array([152, 101, 201], dtype=int64),
#   array([115, 220, 152], dtype=int64),
#   array([152, 201,  23], dtype=int64),
#   array([152,  23,  22], dtype=int64),
#   array([115, 152, 241], dtype=int64),
#   array([ 24, 201, 135], dtype=int64),
#   array([123, 203,  91], dtype=int64),
#   array([193, 217,  91], dtype=int64),
#   array([144, 226,  81], dtype=int64),
#   array([266, 269, 140], dtype=int64),
#   array([254, 138, 252], dtype=int64),
#   array([ 99, 147, 212], dtype=int64),
#   array([212,  56,  55], dtype=int64),
#   array([140, 240, 266], dtype=int64),
#   array([140,  55,  54], dtype=int64),
#   array([131, 240, 272], dtype=int64),
#   array([240, 140,  54], dtype=int64),
#   array([266, 240, 131], dtype=int64),
#   array([139, 253,  92], dtype=int64),
#   array([262,  92, 145], dtype=int64),
#   array([131,  92, 253], dtype=int64),
#   array([272,  92, 131], dtype=int64),
#   array([253, 266, 131], dtype=int64),
#   array([145,  92, 229], dtype=int64),
#   array([ 53, 240,  54], dtype=int64),
#   array([244, 145, 105], dtype=int64),
#   array([272,  53,  52], dtype=int64),
#   array([ 53, 272, 240], dtype=int64),
#   array([272,  52, 183], dtype=int64),
#   array([183,  52,  51], dtype=int64),
#   array([ 92, 127, 229], dtype=int64),
#   array([ 92, 183, 127], dtype=int64),
#   array([127, 219, 236], dtype=int64),
#   array([127, 183,  51], dtype=int64),
#   array([236, 219, 119], dtype=int64),
#   array([127, 236, 229], dtype=int64),
#   array([ 51, 219, 127], dtype=int64),
#   array([145, 229,  80], dtype=int64),
#   array([219, 215, 119], dtype=int64),
#   array([183,  92, 272], dtype=int64),
#   array([ 80, 229, 236], dtype=int64),
#   array([ 71, 123, 165], dtype=int64),
#   array([165, 105, 218], dtype=int64),
#   array([165, 218, 275], dtype=int64),
#   array([218, 105, 145], dtype=int64),
#   array([145,  80, 218], dtype=int64),
#   array([124, 275, 218], dtype=int64),
#   array([132, 198,  91], dtype=int64),
#   array([132, 203, 197], dtype=int64),
#   array([197,  71, 122], dtype=int64),
#   array([203, 123,  71], dtype=int64),
#   array([275, 233,  71], dtype=int64),
#   array([ 71, 197, 203], dtype=int64),
#   array([165, 275,  71], dtype=int64),
#   array([132, 197, 249], dtype=int64),
#   array([124, 218,  80], dtype=int64),
#   array([132,  91, 203], dtype=int64),
#   array([124, 216, 233], dtype=int64),
#   array([124,  80, 216], dtype=int64),
#   array([122, 233, 206], dtype=int64),
#   array([216,  89, 233], dtype=int64),
#   array([236, 216,  80], dtype=int64),
#   array([233, 122,  71], dtype=int64),
#   array([249,  97, 280], dtype=int64),
#   array([249, 197,  97], dtype=int64),
#   array([200, 280,  97], dtype=int64),
#   array([206, 200, 122], dtype=int64),
#   array([280, 200, 137], dtype=int64),
#   array([ 97, 197, 200], dtype=int64),
#   array([200, 197, 122], dtype=int64),
#   array([162, 249, 280], dtype=int64),
#   array([216, 119, 215], dtype=int64),
#   array([275, 124, 233], dtype=int64),
#   array([236, 119, 216], dtype=int64),
#   array([132, 249, 198], dtype=int64),
#   array([ 50, 219,  51], dtype=int64),
#   array([253,  84, 266], dtype=int64),
#   array([215,  89, 216], dtype=int64),
#   array([219,  49, 215], dtype=int64),
#   array([265, 180,  48], dtype=int64),
#   array([215,  48, 180], dtype=int64),
#   array([215, 180,  89], dtype=int64),
#   array([ 77, 200, 206], dtype=int64),
#   array([206,  89, 121], dtype=int64),
#   array([238, 121, 160], dtype=int64),
#   array([121,  89, 180], dtype=int64),
#   array([160, 121, 265], dtype=int64),
#   array([121, 238, 206], dtype=int64),
#   array([180, 265, 121], dtype=int64),
#   array([206, 238,  77], dtype=int64),
#   array([ 48, 215,  49], dtype=int64),
#   array([219,  50,  49], dtype=int64),
#   array([ 47, 160, 265], dtype=int64),
#   array([ 46,  45, 278], dtype=int64),
#   array([ 47,  46, 278], dtype=int64),
#   array([ 90, 160, 278], dtype=int64),
#   array([278, 160,  47], dtype=int64),
#   array([ 45, 173, 278], dtype=int64),
#   array([ 45, 246, 173], dtype=int64),
#   array([246,  44, 174], dtype=int64),
#   array([173,  90, 278], dtype=int64),
#   array([ 45,  44, 246], dtype=int64),
#   array([238, 160,  90], dtype=int64),
#   array([ 47, 265,  48], dtype=int64),
#   array([113, 173, 246], dtype=int64),
#   array([ 77, 177, 213], dtype=int64),
#   array([ 77, 238, 177], dtype=int64),
#   array([177,  90, 151], dtype=int64),
#   array([173, 113, 224], dtype=int64),
#   array([ 90, 177, 238], dtype=int64),
#   array([ 90, 173, 224], dtype=int64),
#   array([137, 213, 114], dtype=int64),
#   array([137, 200, 213], dtype=int64),
#   array([177, 114, 213], dtype=int64),
#   array([177, 151, 114], dtype=int64),
#   array([ 75, 151, 224], dtype=int64),
#   array([137, 114, 187], dtype=int64),
#   array([ 90, 224, 151], dtype=int64),
#   array([151, 187, 114], dtype=int64),
#   array([113, 182, 224], dtype=int64),
#   array([200,  77, 213], dtype=int64),
#   array([174, 258,  96], dtype=int64),
#   array([258, 174,  43], dtype=int64),
#   array([ 43,  42, 258], dtype=int64),
#   array([113, 246, 174], dtype=int64),
#   array([258,  42, 163], dtype=int64),
#   array([ 75, 224, 182], dtype=int64),
#   array([182, 174,  96], dtype=int64),
#   array([ 42,  40, 163], dtype=int64),
#   array([ 96, 258, 163], dtype=int64),
#   array([ 96, 163, 208], dtype=int64),
#   array([41, 40, 42], dtype=int64),
#   array([ 96, 221, 182], dtype=int64),
#   array([174, 182, 113], dtype=int64),
#   array([174,  44,  43], dtype=int64),
#   array([ 40,  39, 163], dtype=int64),
#   array([206, 233,  89], dtype=int64),
#   array([202, 280, 137], dtype=int64),
#   array([101, 152, 220], dtype=int64),
#   array([220, 198,  76], dtype=int64),
#   array([ 76, 172, 220], dtype=int64),
#   array([250, 172, 104], dtype=int64),
#   array([249,  76, 198], dtype=int64),
#   array([220, 172, 101], dtype=int64),
#   array([101, 222, 135], dtype=int64),
#   array([101, 172, 222], dtype=int64),
#   array([250,  82, 222], dtype=int64),
#   array([ 82, 250, 184], dtype=int64),
#   array([172, 250, 222], dtype=int64),
#   array([222,  82, 134], dtype=int64),
#   array([172,  76, 162], dtype=int64),
#   array([135, 201, 101], dtype=int64),
#   array([162, 104, 172], dtype=int64),
#   array([104, 162, 202], dtype=int64),
#   array([104, 202, 259], dtype=int64),
#   array([ 70, 202, 137], dtype=int64),
#   array([162, 280, 202], dtype=int64),
#   array([259, 202,  70], dtype=int64),
#   array([268,  82, 184], dtype=int64),
#   array([268, 184, 103], dtype=int64),
#   array([103, 136, 214], dtype=int64),
#   array([259, 195, 103], dtype=int64),
#   array([268, 103, 168], dtype=int64),
#   array([259, 103, 184], dtype=int64),
#   array([184, 104, 259], dtype=int64),
#   array([168, 103, 214], dtype=int64),
#   array([214, 188,  79], dtype=int64),
#   array([184, 250, 104], dtype=int64),
#   array([162,  76, 249], dtype=int64),
#   array([ 82, 268, 231], dtype=int64),
#   array([235,  25,  24], dtype=int64),
#   array([235, 135, 134], dtype=int64),
#   array([134, 231, 209], dtype=int64),
#   array([134, 135, 222], dtype=int64),
#   array([231, 134,  82], dtype=int64),
#   array([235, 134,  26], dtype=int64),
#   array([25, 26, 27], dtype=int64),
#   array([ 25, 235,  26], dtype=int64),
#   array([ 28,  27, 228], dtype=int64),
#   array([209,  27,  26], dtype=int64),
#   array([209, 228,  27], dtype=int64),
#   array([134, 209,  26], dtype=int64),
#   array([209, 231, 100], dtype=int64),
#   array([ 24, 135, 235], dtype=int64),
#   array([100, 168, 273], dtype=int64),
#   array([168, 100, 231], dtype=int64),
#   array([273,  79, 204], dtype=int64),
#   array([ 79, 273, 168], dtype=int64),
#   array([168, 214,  79], dtype=int64),
#   array([100, 273, 228], dtype=int64),
#   array([133,  28, 228], dtype=int64),
#   array([ 28, 133,  29], dtype=int64),
#   array([133, 204, 242], dtype=int64),
#   array([133, 228, 273], dtype=int64),
#   array([118, 242, 204], dtype=int64),
#   array([133, 242,  29], dtype=int64),
#   array([273, 204, 133], dtype=int64),
#   array([ 29, 242,  30], dtype=int64),
#   array([204,  79, 237], dtype=int64),
#   array([100, 228, 209], dtype=int64),
#   array([268, 168, 231], dtype=int64),
#   array([28, 29, 30], dtype=int64),
#   array([195, 259,  70], dtype=int64),
#   array([115, 198, 220], dtype=int64),
#   array([187, 107, 195], dtype=int64),
#   array([107, 187, 243], dtype=int64),
#   array([107, 243, 170], dtype=int64),
#   array([243, 187, 151], dtype=int64),
#   array([187,  70, 137], dtype=int64),
#   array([170, 243,  75], dtype=int64),
#   array([214, 136, 188], dtype=int64),
#   array([136, 195, 223], dtype=int64),
#   array([223, 170,  86], dtype=int64),
#   array([223, 195, 107], dtype=int64),
#   array([285,  86, 170], dtype=int64),
#   array([136, 223, 188], dtype=int64),
#   array([107, 170, 223], dtype=int64),
#   array([188, 223,  86], dtype=int64),
#   array([170,  75, 221], dtype=int64),
#   array([187, 195,  70], dtype=int64),
#   array([221, 143, 112], dtype=int64),
#   array([221,  96, 143], dtype=int64),
#   array([143, 208,  38], dtype=int64),
#   array([ 39, 208, 163], dtype=int64),
#   array([ 75, 182, 221], dtype=int64),
#   array([ 38, 208,  39], dtype=int64),
#   array([159, 285, 112], dtype=int64),
#   array([285, 170, 112], dtype=int64),
#   array([234,  38,  37], dtype=int64),
#   array([234, 112, 143], dtype=int64),
#   array([159, 112, 234], dtype=int64),
#   array([143,  38, 234], dtype=int64),
#   array([ 86, 285, 159], dtype=int64),
#   array([39, 40, 38], dtype=int64),
#   array([112, 170, 221], dtype=int64),
#   array([243, 151,  75], dtype=int64),
#   array([ 37, 159, 234], dtype=int64),
#   array([237, 188, 111], dtype=int64),
#   array([118, 204, 237], dtype=int64),
#   array([157, 111, 276], dtype=int64),
#   array([111, 157, 237], dtype=int64),
#   array([188, 281, 111], dtype=int64),
#   array([237, 157, 118], dtype=int64),
#   array([242, 186,  30], dtype=int64),
#   array([118, 186, 242], dtype=int64),
#   array([ 31, 186,  32], dtype=int64),
#   array([248, 186, 118], dtype=int64),
#   array([ 32, 186, 248], dtype=int64),
#   array([186,  31,  30], dtype=int64),
#   array([118, 157, 248], dtype=int64),
#   array([157,  33, 248], dtype=int64),
#   array([188, 237,  79], dtype=int64),
#   array([178, 276, 111], dtype=int64),
#   array([178, 281, 159], dtype=int64),
#   array([159,  36, 178], dtype=int64),
#   array([ 36, 159,  37], dtype=int64),
#   array([188,  86, 281], dtype=int64),
#   array([178,  36,  35], dtype=int64),
#   array([ 32, 248,  33], dtype=int64),
#   array([276,  35,  34], dtype=int64),
#   array([ 35, 276, 178], dtype=int64),
#   array([34, 35, 33], dtype=int64),
#   array([ 34,  33, 157], dtype=int64),
#   array([ 34, 157, 276], dtype=int64),
#   array([33, 35, 36], dtype=int64),
#   array([111, 281, 178], dtype=int64),
#   array([ 86, 159, 281], dtype=int64),
#   array([103, 195, 136], dtype=int64),
#   array([143,  96, 208], dtype=int64),
#   array([105, 165, 226], dtype=int64)])

# %% [markdown]
# In the cell below, we transfer the `p` and `t` arrays to Python to be used for plotting.

# %%
p, t = %julia p, t

# %% [markdown]
# To plot the triangular mesh, we need to plot both the polygon and the triangles overlaid. To this end, we first call the `plot_polygon` function on the polygon and then iterate through each triangle to plot a _closed_ triangle using the indices in `t` and the nodes in `p`.

# %%
def plot_triangulation(pv, p, t):
    """
    Plots polygon and triangular mesh
    
    Arguments:
        pv - list of points that describe closed polygon
        p  - list of nodes for the triangular mesh
        t  - list of lists of indices of p that form triangles, 1-indexed
    """
    plot_polygon(pv)
    for tri in t:
        x, y = [p[i-1][0] for i in list(tri) + [tri[0]]], [p[i-1][1] for i in list(tri) + [tri[0]]]
        plt.plot(x, y, color = "black", linewidth=0.5)
        
plot_triangulation(poly, p, t)
plt.title("Trinagular Mesh of Polygon");

# %% [markdown]
# For ease of use, we put this entire pipeline into a function `generate_and_plot_mesh` which can optionally return the arrays `p` and `t`.

# %%
def generate_and_plot_mesh(pv, hmax=0.2, return_p_t = False):
    """
    Generates and plots triangular mesh of a closed polygon
    
    Arguments:
        pv         - list of points that describe a closed polygon
        hmax       - parameter to describe density of triangles
        return_p_t - bool; whether or not to return list of nodes `p` 
                     and list of indices of nodes `t`
    """
    # %julia p,t = pmesh($pv, $hmax)
    p, t = %julia p, t
    plot_triangulation(pv, p, t)
    
    if return_p_t:
        return p, t
    
generate_and_plot_mesh([[0,0], [1,3], [2,5], [3,4], [5,6], [4,1], [0,0]])

# %% [markdown]
# ### State Meshes
#
# To generate the triangular meshes of states, we first need to reorder the coordinates. Because latitude and longitude pairs are recorded as $(\text{lat},\text{lon})$ but longitude is on the $x$-axis, we need to reorder all of these pairs in the `polygons` dictionary. The function `state_to_poly` below takes a state name as its argument and returns a list of $(\text{lon},\text{lat})$ pairs to be used as a polygon.

# %%
def state_to_poly(state):
    """
    Converts (lat, lon) pairs for a state to (lon, lat) for use
    as a polygon
    
    Arguments:
        state - state name to be converted
    """
    points = polygons[state]
    x, y = [point[1] for point in points], [point[0] for point in points]
    return [[xi, yi] for xi, yi in zip(x, y)]

# %% [markdown]
# As a sanity check, we use the two cells below to verify that the plots end up the same (with some style differences, of course).

# %%
plot_state("Alaska")

# %%
plot_polygon(state_to_poly("Alaska"))

# %% [markdown]
# Now, to generate the triangular mesh, we simply pass the array of points to the `generate_and_plot_mesh` function. We set the value of `hmax` to be 2 because if left at its default this algorithm would attempt to generate too many triangles.

# %%
generate_and_plot_mesh(state_to_poly("Alaska"), 2)

# %% [markdown]
# ### Optimizing `hmax`
#
# The `hmax` parameter determines the number of nodes that are generated in the mesh by limiting how small the areas of the triangles can be. If the value is too small, then the algorithm takes too long and the mesh has too many triangles. If it is too large, there aren't enough triangles. To determine the best value of `hmax`, we find the change in longitude $|\max\{\text{longitudes}\} - \min\{\text{longitudes}\}|$ and then divide it by a factor (defaulted to 20).

# %%
def find_hmax(state, factor=20):
    """
    Hyperparameter search function to determine the value of hmax for
    a state based on its width (the maximum change in longitude)
    
    Arguments:
        state  - state to be considered
        factor - factor to divide change in longitude by; lower means
                 fewer nodes
    """
    lons = [pt[1] for pt in polygons[state]]
    max_lon, min_lon = max(lons), min(lons)
    return abs(max_lon - min_lon) / factor

# %% [markdown]
# ### Widget-izing the Mesh Generator
#
# Finally, we put this entire pipeline from choosing `hmax` to plotting the mesh into a function, `plot_state_mesh`, and create an IPython widget that lets you choose a state and set the value of the factor that goes into calculating `hmax`.

# %%
def plot_state_mesh(state, factor):
    """
    Generates triangular mesh of state and plots the mesh
    
    Arguments:
        state  - state to be considered
        factor - factor to be used when calculating hmax
    """
    hmax = find_hmax(state, factor)
    poly = state_to_poly(state)
    generate_and_plot_mesh(poly, hmax)
    plt.title("Trinagular Mesh of {}".format(state))

interact(
    plot_state_mesh,
    state = widgets.Dropdown(
        options = sorted(list(polygons.keys()))
    ),
    factor = widgets.FloatText(
        value = 20,
        description = 'hmax factor',
        disabled = False
    )
);
# Out:
# interactive(children=(Dropdown(description='state', options=('Alabama', 'Alaska', 'Arizona', 'Arkansas', 'Cali…
